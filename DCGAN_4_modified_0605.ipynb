# %% [markdown]
# This is the implementation of DCGAN with normalize input and one-sided label smoothing:
# - Number of epochs: 100
# - lr: 0.0002
# - Add results dir for images and loss
# - Add weight_decay: 1e-4
#
# - input: normalize (0.5, 0.5, 0.5)
# - sided_label real: 0.9 ```torch.from_numpy(np.full(batch_size, 0.9, np.float32))```
# - fake label: 0.3
# - Freezing: stop update D when loss D < 0.7 loss G

# %% [markdown]
# # Import

# %%
import argparse
import os
import time
import pickle
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.autograd import Variable
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image
from torchnet.meter import AverageValueMeter

# %% [markdown]
# # Define Arguments

# %%
# %ll ./data/ut-zap50k/Shoes/Sneakers_and_athletic_shoes/
# Out:
# total 1568
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 7 For All Mankind Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas by Stella McCartney/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas Golf/
# drwxrwxr-x 2 hminle 12288  4월 23 13:42 adidas Kids/
# drwxrwxr-x 2 hminle 12288  4월 23 13:42 adidas Originals/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas Originals Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas Outdoor/
# drwxrwxr-x 2 hminle 12288  4월 23 13:42 adidas Running/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 adidas Y-3 by Yohji Yamamoto/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Aetrex/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Agatha Ruiz De La Prada Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ahnu/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 ALDO/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Alexander McQueen/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Allrounder by Mephisto/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Altra Zero Drop Footwear/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Amiana/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Anne Klein/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Arcopedico/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ariat/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Armani Jeans/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ashworth/
# drwxrwxr-x 2 hminle 20480  4월 23 13:42 ASICS/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 ASICS Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Asolo/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Aster Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Avia/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Axion/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 BC Footwear/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Beeko/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ben Sherman/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Betsey Johnson/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Bikkembergs/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Bloch/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Bloch Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Blowfish/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Body Glove/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Bogs/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Born/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 BOSS Green/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 BOSS Orange/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Bottega Veneta/
# drwxrwxr-x 2 hminle 12288  4월 23 13:42 Brooks/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Brooks Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Burberry/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Callaway/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Call it SPRING/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Calvin Klein/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Calvin Klein Jeans/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Camper/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Camper Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Capezio/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Capezio Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Caterpillar/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Chaco/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Chaco Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Chicago Skates/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Chrome/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Cienta Kids Shoes/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Circa/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Circa Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Clae/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Clarks/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Cobian/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Cole Haan/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Cole Haan Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Columbia/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Converse/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Converse by John Varvatos/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Converse Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Costume National/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Creative Recreation/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Creative Recreation Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Crocs/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Crocs Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Cushe/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dansko/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 David Tate/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 DC/
# drwxrwxr-x 2 hminle 12288  4월 23 13:42 DC Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Deer Stags/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dexter Bowling/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Diadora/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Diadora Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Diesel/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dirk Bikkembergs/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 DKNY/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dolce & Gabbana/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Drew/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dr. Martens/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 DSQUARED2/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Dunham/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 DVS Shoe Company/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Easy Spirit/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 ECCO/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 ECCO Golf/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ecco Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 ECCO Sport/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ed Hardy/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ektelon/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Element/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Elizabeth and James/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 El Naturalista/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Emerald by Element/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Emerica/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 etnies/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 etnies Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 EVOLV/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Fallen/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Fila/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Finn Comfort/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 FitFlop/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Five Ten/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Fox/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Fratelli Rossetti/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Fred Perry/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Frye/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Frye Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Gabor/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Garmont/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 GBX/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Generic Surplus/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Geox Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Giro/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Giuseppe Zanotti/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Globe/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Globe Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Gola/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 GoLite/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Gravis/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 GUESS/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 GUESS Kids'/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Habitat/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Heelys/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Hi-Tec/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Hi-Tec Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Hoka One One/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 HUGO/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Hush Puppies/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Hush Puppies Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 inov-8/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Ipath/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 J-41/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Jambu/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Jambu Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Jessica Simpson Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 John Varvatos/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Josef Seibel/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Juicy Couture/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Juicy Couture Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Jumping Jacks Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Just Cavalli/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 K2 Skates/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Kalso Earth/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 

# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Vivobarefoot/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 VOLATILE/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Volatile Kids/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Wilson/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Wolverine/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Zamberlan/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Zero/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Zigi/
# drwxrwxr-x 2 hminle  4096  4월 23 13:42 Zoot Sports/

# %%
parser = {
    'data_path': './data/ut-zap50k/Shoes/Sneakers_and_athletic_shoes/',
    'epochs': 100,
    'batch_size': 64,
    'lr': 0.0002,
    'image_size': 136,
    'scale_size': 64,
    'z_dim': 100,
    'G_features': 64,
    'D_features': 64,
    'image_channels': 3,
    'beta1': 0.5,
    'cuda': True,
    'seed': 7,
    'workers': 2,
    'results': './resultsDCGAN4_0605/'
}
args = argparse.Namespace(**parser)
args.image_results = args.results + 'images/'
args.loss_results = args.results + 'loss/'
args.cuda = args.cuda and torch.cuda.is_available()

if not os.path.isdir(args.data_path):
    os.makedirs(args.data_path)
if not os.path.isdir(args.results):
    os.makedirs(args.results)
if not os.path.isdir(args.image_results):
    os.makedirs(args.image_results)
if not os.path.isdir(args.loss_results):
    os.makedirs(args.loss_results)
    
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %% [markdown]
# # Prepare Data

# %% [markdown]
# **Note: all iamges have size 136x102**

# %%
from folder import ImageFolder

# %%
from torchvision.transforms import ToPILImage
to_image = ToPILImage()

# %%
def get_loader(image_root, batch_size, scale_size, num_workers=2, shuffle=True):
    #image_root = os.path.join(root, 'splits', split)
    dataset = ImageFolder(root=image_root, transform=transforms.Compose([
            transforms.Pad(34, fill=(255, 255, 255)), # padding images with (255,255,255) --> pad 255 in 3 channels
            transforms.CenterCrop((136,136)),
            transforms.Scale(scale_size),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]))

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle, num_workers=int(num_workers))
    #data_loader.shape = [int(num) for num in dataset[0][0].size()]

    return data_loader

# %%
dataloader = get_loader(args.data_path, args.batch_size, args.scale_size)
# Out:
# Found 12856 images in subfolders of: ./data/ut-zap50k/Shoes/Sneakers_and_athletic_shoes/

# %% [markdown]
# ## Test One Image

# %%
test_image = 0
for data, _ in dataloader:
    print(data[0])
    test_image = data[0]
    break
# Out:
# (0 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# (1 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# (2 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
# [torch.FloatTensor of size 3x64x64]

# %%
to_image(test_image)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F4B9F9EC908>

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Define G

# %%
class _netG(nn.Module):
    def __init__(self):
        super(_netG, self).__init__()
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d(args.z_dim, args.G_features * 8,
                               4, 1, 0, bias=False),
            nn.BatchNorm2d(args.G_features * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(args.G_features * 8, args.G_features * 4,
                               4, 2, 1, bias=False),
            nn.BatchNorm2d(args.G_features * 4),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(args.G_features * 4, args.G_features * 2,
                               4, 2, 1, bias=False),
            nn.BatchNorm2d(args.G_features * 2),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d(args.G_features * 2, args.G_features,
                               4, 2, 1, bias=False),
            nn.BatchNorm2d(args.G_features),
            nn.ReLU(True),
            # state size. (ngf) x 16 x 16
            nn.ConvTranspose2d(args.G_features, args.image_channels,
                               4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 32 x 32
        )
        self._initialize_weights()
        
    # custom weight initialization
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                init.normal(m.weight, mean=0, std=0.02)
            elif isinstance(m, nn.BatchNorm2d):
                init.normal(m.weight, mean=1, std=0.02)
                init.constant(m.bias, 0)

    def forward(self, x):
        return self.main(x)

# %% [markdown]
# ## Define D

# %%
class _netD(nn.Module):
    def __init__(self):
        super(_netD, self).__init__()
        self.main = nn.Sequential(
            # input is (nc) x 32 x 32
            nn.Conv2d(args.image_channels, args.D_features,
                      4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 16 x 16
            nn.Conv2d(args.D_features, args.D_features * 2,
                      4, 2, 1, bias=False),
            nn.BatchNorm2d(args.D_features * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 8 x 8
            nn.Conv2d(args.D_features * 2, args.D_features * 4,
                      4, 2, 1, bias=False),
            nn.BatchNorm2d(args.D_features * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(args.D_features * 4, args.D_features * 8,
                      4, 2, 1, bias=False),
            nn.BatchNorm2d(args.D_features * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 4 x 4
            nn.Conv2d(args.D_features * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )
        self._initialize_weights()
        
    # custom weight initialization
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                init.normal(m.weight, mean=0, std=0.02)
            elif isinstance(m, nn.BatchNorm2d):
                init.normal(m.weight, mean=1, std=0.02)
                init.constant(m.bias, 0)

    def forward(self, input):
        output = self.main(input)
        return output.view(-1, 1)

# %% [markdown]
# ## Save losses

# %%
class Results():
    def __init__(self, results_path):
        self.D_losses = []
        self.G_losses = []
        self.D_reals = []
        self.D_fakes = []
        self.G_reals = []
        self.results_path = results_path
    
    def save_losses(self, D_loss, G_loss, D_real, D_fake, G_real):
        self.D_losses.append(D_loss)
        self.G_losses.append(G_loss)
        self.D_reals.append(D_real)
        self.D_fakes.append(D_fake)
        self.G_reals.append(G_real)
        
    def save_to_disk(self):
        f = open(self.results_path + "D_losses.pkl", "wb")
        pickle.dump(self.D_losses, f)
        f= open(self.results_path + "G_losses.pkl", "wb")
        pickle.dump(self.G_losses, f)
        f = open(self.results_path + "D_reals.pkl", "wb")
        pickle.dump(self.D_reals, f)
        f = open(self.results_path + "D_fakes.pkl", "wb")
        pickle.dump(self.D_fakes, f)
        f = open(self.results_path + "G_reals.pkl", "wb")
        pickle.dump(self.G_reals, f)

# %% [markdown]
# ## Define Train and Generate

# %%
def train(args, data_loader, netG, netD, G_optimizer, D_optimizer,
          criterion, epoch, result_losses):
    D_losses = AverageValueMeter()
    G_losses = AverageValueMeter()
    D_reals = AverageValueMeter()
    D_fakes = AverageValueMeter()
    G_reals = AverageValueMeter()
    
    start = time.time()
    # call Variable after .cuda()
    for i, (real, _) in enumerate(data_loader):
        batch_size = real.size(0)
        real_label = torch.from_numpy(np.full(batch_size, 0.9, np.float32)) #modify here
        fake_label = torch.from_numpy(np.full(batch_size, 0.3, np.float32))
        z = torch.randn(batch_size, args.z_dim, 1, 1)
        
        if args.cuda:
            real_label = real_label.cuda()
            fake_label = fake_label.cuda()
            real = real.cuda()
            z = z.cuda()
        real_label = Variable(real_label)
        fake_label = Variable(fake_label)
        real = Variable(real)
        z = Variable(z)
        
        if D_losses.value()[0] < 0.7*G_losses.value()[0]:
            # Stop training D
            #----------TRAIN D---------------
            # train with real
            real_output = netD(real)
            D_real_loss = criterion(real_output, real_label)
            D_real = real_output.data.mean()
        
            # train with fake
            fake = netG(z)
            fake_output = netD(fake.detach())
            D_fake_loss = criterion(fake_output, fake_label)
            D_fake = fake_output.data.mean()
        
            # loss D
            D_loss = D_real_loss + D_fake_loss
            #netD.zero_grad()
            #D_loss.backward()
            #D_optimizer.step()
            
            #----------TRAIN G---------------
            output = netD(fake)
            G_loss = criterion(output, real_label)
            G_real = output.data.mean()
            netG.zero_grad()
            G_loss.backward()
            G_optimizer.step()    
        else:
            #----------TRAIN D---------------
            # train with real
            real_output = netD(real)
            D_real_loss = criterion(real_output, real_label)
            D_real = real_output.data.mean()
        
            # train with fake
            fake = netG(z)
            fake_output = netD(fake.detach())
            D_fake_loss = criterion(fake_output, fake_label)
            D_fake = fake_output.data.mean()
        
            # loss D
            D_loss = D_real_loss + D_fake_loss
            netD.zero_grad()
            D_loss.backward()
            D_optimizer.step()
            
            #----------TRAIN G---------------
            output = netD(fake)
            G_loss = criterion(output, real_label)
            G_real = output.data.mean()
            netG.zero_grad()
            G_loss.backward()
            G_optimizer.step()
        
        
        # update loss
        D_losses.add(D_loss.data.cpu()[0] * batch_size, batch_size)
        G_losses.add(G_loss.data.cpu()[0] * batch_size, batch_size)
        D_reals.add(D_real * batch_size, batch_size)
        D_fakes.add(D_fake * batch_size, batch_size)
        G_reals.add(G_real * batch_size, batch_size)
        
    print("=> EPOCH {} | Time: {}s | D_loss: {:.4f} | G_loss: {:.4f}"
          " | D_real: {:.4f} | D_fake: {:.4f} | G_real: {:.4f}"
          .format(epoch, round(time.time()-start), D_losses.value()[0],
                  G_losses.value()[0], D_reals.value()[0],
                  D_fakes.value()[0], G_reals.value()[0]))
    result_losses.save_losses(D_losses.value()[0],
                  G_losses.value()[0], D_reals.value()[0],
                  D_fakes.value()[0], G_reals.value()[0])

# %%
def generate(args, netG, epoch):
    z = torch.randn(args.batch_size, args.z_dim, 1, 1)
    if args.cuda:
        z = z.cuda()
    fake = netG(Variable(z, volatile=True))
    save_image(fake.data.cpu(), os.path.join(args.image_results,
        "fake_sample_epoch_{:02d}.png".format(epoch)), normalize=True)

# %% [markdown]
# ## Create Model, Define Loss and Optimizer

# %%
netG = _netG()
netD = _netD()
criterion = nn.BCELoss()
if args.cuda:
    netD.cuda()
    netG.cuda()
    criterion.cuda()

# %%
D_optimizer = optim.Adam(netD.parameters(), lr=args.lr,
                         betas=(args.beta1, 0.999), weight_decay=1e-4)
G_optimizer = optim.Adam(netG.parameters(), lr=args.lr,
                         betas=(args.beta1, 0.999), weight_decay=1e-4)

# %% [markdown]
# ## Run Train

# %%
result_losses = Results(args.loss_results)
for epoch in range(0, args.epochs):
    train(args, dataloader, netG, netD, G_optimizer, D_optimizer,
          criterion, epoch, result_losses)
    generate(args, netG, epoch)
# Out:
# => EPOCH 0 | Time: 37s | D_loss: 2.6212 | G_loss: 3.6538 | D_real: 0.6612 | D_fake: 0.5650 | G_real: 0.4037
# => EPOCH 1 | Time: 46s | D_loss: 1.2328 | G_loss: 1.2933 | D_real: 0.7639 | D_fake: 0.4264 | G_real: 0.3314
# => EPOCH 2 | Time: 46s | D_loss: 1.1949 | G_loss: 1.1834 | D_real: 0.7617 | D_fake: 0.4389 | G_real: 0.3530
# => EPOCH 481 | Time: 46s | D_loss: 0.9530 | G_loss: 1.1674 | D_real: 0.8885 | D_fake: 0.3110 | G_real: 0.2961
# => EPOCH 482 | Time: 46s | D_loss: 0.9530 | G_loss: 1.1688 | D_real: 0.8894 | D_fake: 0.3109 | G_real: 0.2951
# => EPOCH 483 | Time: 46s | D_loss: 0.9524 | G_loss: 1.1750 | D_real: 0.8897 | D_fake: 0.3103 | G_real: 0.2949
# => EPOCH 484 | Time: 46s | D_loss: 0.9539 | G_loss: 1.1768 | D_real: 0.8885 | D_fake: 0.3114 | G_real: 0.2938
# => EPOCH 485 | Time: 46s | D_loss: 0.9502 | G_loss: 1.1721 | D_real: 0.8903 | D_fake: 0.3100 | G_real: 0.2935
# => EPOCH 486 | Time: 47s | D_loss: 0.9561 | G_loss: 1.1858 | D_real: 0.8870 | D_fake: 0.3127 | G_real: 0.2968
# => EPOCH 487 | Time: 48s | D_loss: 0.9549 | G_loss: 1.1879 | D_real: 0.8872 | D_fake: 0.3127 | G_real: 0.2940
# => EPOCH 488 | Time: 47s | D_loss: 0.9523 | G_loss: 1.1823 | D_real: 0.8891 | D_fake: 0.3111 | G_real: 0.2939
# => EPOCH 489 | Time: 46s | D_loss: 0.9559 | G_loss: 1.1915 | D_real: 0.8879 | D_fake: 0.3117 | G_real: 0.2953
# => EPOCH 490 | Time: 47s | D_loss: 0.9552 | G_loss: 1.1979 | D_real: 0.8869 | D_fake: 0.3132 | G_real: 0.2929
# => EPOCH 491 | Time: 46s | D_loss: 0.9540 | G_loss: 1.1912 | D_real: 0.8882 | D_fake: 0.3118 | G_real: 0.2925
# => EPOCH 492 | Time: 46s | D_loss: 0.9531 | G_loss: 1.1828 | D_real: 0.8884 | D_fake: 0.3117 | G_real: 0.2940
# => EPOCH 493 | Time: 46s | D_loss: 0.9545 | G_loss: 1.1882 | D_real: 0.8882 | D_fake: 0.3116 | G_real: 0.2957
# => EPOCH 494 | Time: 48s | D_loss: 0.9550 | G_loss: 1.1901 | D_real: 0.8874 | D_fake: 0.3122 | G_real: 0.2949
# => EPOCH 495 | Time: 47s | D_loss: 0.9544 | G_loss: 1.1909 | D_real: 0.8876 | D_fake: 0.3123 | G_real: 0.2935
# => EPOCH 496 | Time: 47s | D_loss: 0.9563 | G_loss: 1.2086 | D_real: 0.8865 | D_fake: 0.3137 | G_real: 0.2916
# => EPOCH 497 | Time: 47s | D_loss: 0.9580 | G_loss: 1.1967 | D_real: 0.8855 | D_fake: 0.3144 | G_real: 0.2956
# => EPOCH 498 | Time: 47s | D_loss: 0.9518 | G_loss: 1.1824 | D_real: 0.8883 | D_fake: 0.3118 | G_real: 0.2930
# => EPOCH 499 | Time: 46s | D_loss: 0.9543 | G_loss: 1.1966 | D_real: 0.8864 | D_fake: 0.3106 | G_real: 0.2935

# %% [markdown]
# ## Save loss

# %%
result_losses.save_to_disk()

# %% [markdown]
# ## Get one REAL Image

# %%
sample, _ = iter(dataloader).next()
save_image(sample, os.path.join(args.results, "real_sample.png"))
